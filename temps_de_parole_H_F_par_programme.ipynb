# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df = pd.read_csv("data/ina-csa-parole-femmes-genreprogramme.csv") 
print(df.dtypes)
df.head()
# Out:
# genre                                object
# nb_declarations_2020                  int64
# total_declarations_duration_2020    float64
# women_speech_duration_2020          float64
# men_speech_duration_2020            float64
# other_duration_2020                 float64
# women_expression_rate_2020          float64
# speech_rate_2020                    float64
# nb_declarations_2019                float64
# total_declarations_duration_2019    float64
# women_speech_duration_2019          float64
# men_speech_duration_2019            float64
# other_duration_2019                 float64
# women_expression_rate_2019          float64
# speech_rate_2019                    float64
# dtype: object
#                             genre  nb_declarations_2020  \
# 0           Information - Journal                 11770
# 1          Information - Magazine                  8839
# 2  Information - Autres émissions                   475
# 3                    Documentaire                   737
# 4                        Magazine                 18189
#
#    total_declarations_duration_2020  women_speech_duration_2020  \
# 0                       31573605.20                 10733020.96
# 1                       43921146.18                 12265253.54
# 2                         873112.46                   286694.28
# 3                        2471803.82                   710360.96
# 4                       56430421.82                 18222632.14
#
#    men_speech_duration_2020  other_duration_2020  women_expression_rate_2020  \
# 0               16666252.56           4174331.68                    0.391726
# 1               28520630.38           3135262.26                    0.300723
# 2                 489202.08             97216.10                    0.369501
# 3                1159896.78            601546.08                    0.379820
# 4               28479390.24           9728399.44                    0.390189
#
#    speech_rate_2020  nb_declarations_2019  total_declarations_duration_2019  \
# 0          0.867790               12172.0                       46426696.82
# 1          0.928616               10773.0                       53435793.92
# 2          0.888656                   NaN                               NaN
# 3          0.756637                 521.0                        1834222.64
# 4          0.827604               15113.0                       45898496.56
#
#    women_speech_duration_2019  men_speech_duration_2019  other_duration_2019  \
# 0                 15227561.64               23912775.34           7286359.84
# 1                 14629241.66               33703544.66           5103007.60
# 2                         NaN                       NaN                  NaN
# 3                   537780.72                 947300.84            349141.08
# 4                 14600771.90               24428136.00           6869588.66
#
#    women_expression_rate_2019  speech_rate_2019
# 0                    0.389050          0.843057
# 1                    0.302677          0.904502
# 2                         NaN               NaN
# 3                    0.362122          0.809652
# 4                    0.374101          0.850331

# %%
#j'utilise la fonction fillna() pour du coup remplacer les valeurs manquantes par 0, mais je peux choisir n'importe quel chiffre
df['men_speech_duration_2019'].fillna(0, inplace = True)
df['nb_declarations_2019'].fillna(0, inplace = True)
df['total_declarations_duration_2019'].fillna(0, inplace = True)
df['women_speech_duration_2019'].fillna(0, inplace = True)
#je peux aussi utiliser sans (inplace) comme ca : 
df['other_duration_2019'] = df['other_duration_2019'].fillna(0)
df['women_expression_rate_2019'] = df['women_expression_rate_2019'].fillna(0)
df['speech_rate_2019'] = df['speech_rate_2019'].fillna(0)
df.head(50)
# Out:
# C:\Users\Jayan\AppData\Local\Temp\ipykernel_28540\1782047950.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['men_speech_duration_2019'].fillna(0, inplace = True)
# C:\Users\Jayan\AppData\Local\Temp\ipykernel_28540\1782047950.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['nb_declarations_2019'].fillna(0, inplace = True)
# C:\Users\Jayan\AppData\Local\Temp\ipykernel_28540\1782047950.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['total_declarations_duration_2019'].fillna(0, inplace = True)
# C:\Users\Jayan\AppData\Local\Temp\ipykernel_28540\1782047950.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['women_speech_duration_2019'].fillna(0, inplace = True)
#                                                 genre  nb_declarations_2020  \
# 0                               Information - Journal                 11770
# 1                              Information - Magazine                  8839
# 2                      Information - Autres émissions                   475
# 3                                        Documentaire                   737
# 4                                            Magazine                 18189
# 5                           Divertissement - Variétés                   367
# 6                               Divertissement - Jeux                  1494
# 7                             Divertissement - Autres                  2809
# 8                                               Sport                  2485
# 9   Autres émissions - Elément de programme/Habillage                     4
# 10                          Autres émissions - Autres                    61
# 11                                      Non Renseigné                   634
# 12                                            Musique                   572
#
#     total_declarations_duration_2020  women_speech_duration_2020  \
# 0                        31573605.20                 10733020.96
# 1                        43921146.18                 12265253.54
# 2                          873112.46                   286694.28
# 3                         2471803.82                   710360.96
# 4                        56430421.82                 18222632.14
# 5                         2194760.66                   400969.78
# 6                         4478254.94                  1330079.96
# 7                        15923434.16                  2863331.32
# 8                         9112240.78                  1031995.22
# 9                           37552.82                     5989.90
# 10                         939597.08                   350685.48
# 11                        1565437.14                   508041.10
# 12                        7229206.12                   177836.10
#
#     men_speech_duration_2020  other_duration_2020  women_expression_rate_2020  \
# 0                16666252.56           4174331.68                    0.391726
# 1                28520630.38           3135262.26                    0.300723
# 2                  489202.08             97216.10                    0.369501
# 3                 1159896.78            601546.08                    0.379820
# 4                28479390.24           9728399.44                    0.390189
# 5                  742060.04           1051730.84                    0.350796
# 6                 2149085.78            999089.20                    0.382299
# 7                 4544665.44           8515437.40                    0.386519
# 8                 6842492.44           1237753.12                    0.131056
# 9                   16972.44             14590.48                    0.260858
# 10                 508552.64             80358.96                    0.408135
# 11                 913072.08            144323.96                    0.357495
# 12                 226377.76           6824992.26                    0.439955
#
#     speech_rate_2020  nb_declarations_2019  total_declarations_duration_2019  \
# 0           0.867790               12172.0                       46426696.82
# 1           0.928616               10773.0                       53435793.92
# 2           0.888656                   0.0                              0.00
# 3           0.756637                 521.0                        1834222.64
# 4           0.827604               15113.0                       45898496.56
# 5           0.520799                 843.0                        2804138.44
# 6           0.776902                1358.0                        4168509.44
# 7           0.465226                2379.0                       14399727.22
# 8           0.864166                 770.0                        4030843.46
# 9           0.611468                   0.0                              0.00
# 10          0.914475                   0.0                              0.00
# 11          0.907806                   0.0                              0.00
# 12          0.055914                 725.0                        5215657.86
#
#     women_speech_duration_2019  men_speech_duration_2019  other_duration_2019  \
# 0                  15227561.64               23912775.34           7286359.84
# 1                  14629241.66               33703544.66           5103007.60
# 2                         0.00                      0.00                 0.00
# 3                    537780.72                 947300.84            349141.08
# 4                  14600771.90               24428136.00           6869588.66
# 5                   1119862.46                1246383.52            437892.46
# 6                    943693.18                2015160.98           1209655.28
# 7                   2098497.86                4397485.18           7903744.18
# 8                    370891.30                3074599.46            585352.70
# 9                         0.00                      0.00                 0.00
# 10                        0.00                      0.00                 0.00
# 11                        0.00                      0.00                 0.00
# 12                   236472.58                 393271.10           4585914.18
#
#     women_expression_rate_2019  speech_rate_2019
# 0                     0.389050          0.843057
# 1                     0.302677          0.904502
# 2                     0.000000          0.000000
# 3                     0.362122          0.809652
# 4                     0.374101          0.850331
# 5                     0.473265          0.843841
# 6                     0.318939          0.709811
# 7                     0.323045          0.451118
# 8                     0.107645          0.854782
# 9                     0.000000          0.000000
# 10                    0.000000          0.000000
# 11                    0.000000          0.000000
# 12                    0.375506          0.120741

# %%
df1 = pd.DataFrame({
    'genre' : ['Information', 'Documentaire', 'Magazine', 'Divertissement', 'Sport', 'Musique'],
    'men_speech_2019' : [df['men_speech_duration_2019'].head(3).sum(), df['men_speech_duration_2019'].iloc[3], df['men_speech_duration_2019'].iloc[4], df['men_speech_duration_2019'].iloc[6:8].sum(), df['men_speech_duration_2019'].iloc[8], df['men_speech_duration_2019'].iloc[12]],
    'women_speech_2019' : [df['women_speech_duration_2019'].head(3).sum(), df['women_speech_duration_2019'].iloc[3], df['women_speech_duration_2019'].iloc[4], df['women_speech_duration_2019'].iloc[6:8].sum(), df['women_speech_duration_2019'].iloc[8], df['women_speech_duration_2019'].iloc[12]]
})
df1
#en fait avec juste iloc[4] comme ca, ca prend vrm du coup le numero 1 du tableau, dns dans notre caas cest magazine 
#alors que si tu fais iloc[6:8] ca prend du coup la position 5,6,8 en gos faut faire 6 + 1, avec iloc

df2 = pd.DataFrame({
    'genre' : ['Information', 'Documentaire', 'Magazine', 'Divertissement', 'Sport', 'Autres emissions', 'Non renseigné', 'Musique'],
    'men_speech_2020' : [df['men_speech_duration_2020'].head(3).sum(), df['men_speech_duration_2020'].iloc[3], df['men_speech_duration_2020'].iloc[4], df['men_speech_duration_2020'].iloc[6:8].sum(), df['men_speech_duration_2020'].iloc[8],df['men_speech_duration_2020'].iloc[10:11].sum(), df['men_speech_duration_2020'].iloc[11], df['men_speech_duration_2020'].iloc[12]],
    'women_speech_2020' : [df['women_speech_duration_2020'].head(3).sum(), df['women_speech_duration_2020'].iloc[3], df['women_speech_duration_2020'].iloc[4], df['women_speech_duration_2020'].iloc[6:8].sum(), df['women_speech_duration_2020'].iloc[8],df['women_speech_duration_2020'].iloc[10:11].sum(), df['women_speech_duration_2020'].iloc[11], df['women_speech_duration_2020'].iloc[12]]
})
df2
# Out:
#               genre  men_speech_2020  women_speech_2020
# 0       Information      45676085.02        23284968.78
# 1      Documentaire       1159896.78          710360.96
# 2          Magazine      28479390.24        18222632.14
# 3    Divertissement       6693751.22         4193411.28
# 4             Sport       6842492.44         1031995.22
# 5  Autres emissions        508552.64          350685.48
# 6     Non renseigné        913072.08          508041.10
# 7           Musique        226377.76          177836.10

# %%
plt.pie(df1['men_speech_2019'],  autopct= '%1.1f%%', colors= ['red', 'blue', 'green', 'yellow', 'darkviolet', 'orange', 'gold', 'silver'])
plt.title("Diagramme circulaire de temps de parole des hommes en fonction des programmes en 2019") 
plt.legend(labels= df1['genre'], bbox_to_anchor = (-0.2,0.75)) 
plt.show()

# %%
plt.pie(df1['women_speech_2019'], autopct = '%1.1f%%', colors= ['red', 'blue', 'green', 'yellow', 'darkviolet', 'orange', 'gold', 'silver'])
plt.title("Diagramme circulaire de temps de parole des femmes en fonction des programmes en 2019") 
plt.legend(labels= df1['genre'], bbox_to_anchor = (-0.2,0.75)) 
plt.show()

# %%
plt.pie(df2['men_speech_2020'], autopct = '%1.1f%%', colors= ['red', 'blue', 'green', 'yellow', 'darkviolet', 'orange', 'gold', 'silver'])
plt.title("Diagramme circulaire de temps de parole des hommes en fonction des programmes en 2020") 
plt.legend(labels= df2['genre'], bbox_to_anchor = (-0.2,0.75))

# %%
plt.pie(df2['women_speech_2020'], autopct = '%1.1f%%', colors= ['red', 'blue', 'green', 'yellow', 'darkviolet', 'orange', 'gold', 'silver'])
plt.title("Diagramme circulaire de temps de parole des femmes en fonction des programmes en 2020") 
plt.legend(labels= df2['genre'], bbox_to_anchor = (-0.2,0.75))
